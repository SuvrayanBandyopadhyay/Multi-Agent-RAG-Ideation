# %% [markdown]
# # Marketing analysis using EXA and OpenAI

# %%
from exa_py import Exa

import os

exa = Exa('394a39d9-d0cd-4b9d-961b-eb6ec8ef3fc5')

result = exa.search_and_contents(
  "OpenAI Swarm",
  type="neural",
  use_autoprompt=True,
  num_results=20,
  text=True,
)

print(result)
# Out:
# Title: GitHub - openai/swarm: Framework for building, orchestrating and deploying multi-agent systems. Managed by OpenAI Solutions team. Experimental framework.
# URL: https://github.com/openai/swarm
# ID: https://github.com/openai/swarm
# Score: 0.19823376834392548
# Published Date: 2024-02-22T00:00:00.000Z
# Author: Openai
# Image: None
# Text: Swarm (experimental sample)
# An ergonomic, lightweight multi-agent orchestration framework.
#  Warning Swarm is currently an experimental sample framework intended to explore ergonomic interfaces for multi-agent systems. It is not intended to be used in production, and therefore has no official support. (This also means we will not be reviewing PRs or issues!)
# The primary goal of Swarm is to showcase the handoff &amp; routines patterns explored in the Orchestrating Agents: Handoffs &amp; Routines cookbook. It is not meant as a standalone library, and is primarily for educational purposes.
#  Install
# Requires Python 3.10+
# ...
